# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.40MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_to_vocab[5]
# Out:
# 'a'

# %%
int_words[5]
# Out:
# 1

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

from collections import Counter
import random

t = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(t/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()] # The final subsampled word list

# %%
train_words[0]
# Out:
# 5238

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 10
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
print(similarity[1:3])
# Out:
# Tensor("strided_slice:0", shape=(2, 63641), dtype=float32)

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6153 0.0950 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5932 0.0940 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4870 0.0930 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6124 0.0909 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4879 0.0929 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5138 0.0925 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5522 0.0948 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4960 0.0975 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4809 0.0988 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4559 0.1025 sec/batch
# Nearest to of: henry, beaten, patriarchate, photographer, triumph, toffler, plantagenet, antiderivatives,
# Nearest to one: stative, approach, lacquer, realised, oppose, musschenbroek, theophanes, schmidt,
# Nearest to the: holman, bolivian, coroner, combat, otomo, billed, innumerable, barnstorming,
# Nearest to to: megabats, squire, mizrahim, bh, defaults, suva, scorpius, moroccans,
# Nearest to a: sectarian, sprang, raison, iran, unappealing, lz, mezzo, whirling,
# Nearest to and: humphreys, kroni, forster, say, spell, capsized, snippets, scouring,
# Nearest to in: wilbur, zhao, fraternities, telecom, philosophers, squeak, funnel, keeshonden,
# Nearest to two: nursia, bbs, mansion, myopathy, schizophrenia, alemanni, twayne, indicator,
# Nearest to file: suki, metering, choral, lancastrian, galaxies, snapped, gcc, math,
# Nearest to bbc: fine, owing, wintour, dukes, dock, drastic, pars, alexanderplatz,
# Nearest to existence: gyula, ppr, shipment, jamais, brute, metaphysician, kassa, collides,
# Nearest to heavy: noord, maclaine, reorganised, lobito, aegean, banknote, telemark, often,
# Nearest to animals: baptists, remarkably, painters, komo, izmir, purchase, daniell, axiomatization,
# Nearest to units: instrumental, lament, encouraged, inventiveness, yankee, vishnu, amuse, seaweeds,
# Nearest to universe: consanguinity, questionnaire, heiland, dah, xaver, extract, gazetteer, bcs,
# Nearest to know: ingrained, habitual, conviction, undercover, combinations, conformity, calvinball, aggressiveness,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4821 0.1039 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3788 0.1065 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3368 0.1059 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2270 0.1058 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1819 0.1067 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1767 0.1092 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0929 0.1112 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0807 0.1106 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9985 0.1110 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9568 0.1104 sec/batch
# Nearest to of: henry, beaten, fake, mechanism, language, army, photographer, holds,
# Nearest to one: approach, stative, realised, oppose, lacquer, styled, schmidt, cloud,
# Nearest to the: holman, combat, billed, coroner, bolivian, otomo, rolled, holding,
# Nearest to to: covers, properties, megabats, than, squire, directed, texts, conditions,
# Nearest to a: sectarian, iran, sprang, shore, raison, perform, wins, someone,
# Nearest to and: itself, say, reforms, entitled, forster, cd, spell, drama,
# Nearest to in: wilbur, fraternities, philosophers, fewer, zhao, telecom, winter, failed,
# Nearest to two: nursia, indicator, emperor, curbing, preprint, mansion, schizophrenia, bbs,
# Nearest to file: suki, lancastrian, metering, choral, galaxies, snapped, gcc, teletype,
# Nearest to bbc: fine, owing, drastic, dock, dukes, monitors, extend, pars,
# Nearest to existence: ppr, brute, gyula, ban, egyptian, shipment, geneticists, kim,
# Nearest to heavy: noord, maclaine, often, lobito, aegean, airport, reorganised, judicial,
# Nearest to animals: remarkably, purchase, painters, contact, baptists, komo, izmir, inventory,
# Nearest to units: instrumental, encouraged, lament, patterns, disambiguation, planning, inventiveness, yankee,
# Nearest to universe: consanguinity, proposed, call, misconception, questionnaire, extract, forms, heiland,
# Nearest to know: combinations, conviction, habitual, conformity, turnout, hector, aggressiveness, hanssen,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9571 0.1122 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9142 0.1113 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8709 0.1111 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8880 0.1132 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7981 0.1109 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8125 0.1132 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7992 0.1132 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7946 0.1110 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7870 0.1116 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7719 0.1118 sec/batch
# Nearest to of: fake, henry, beaten, surplus, takeover, expansion, preceding, mechanism,
# Nearest to one: realised, george, stative, approach, lacquer, oppose, styled, ailing,
# Nearest to the: holman, coroner, billed, holding, bolivian, conflicts, otomo, reluctance,
# Nearest to to: covers, squire, megabats, supplied, than, messengers, properties, sign,
# Nearest to a: sectarian, sprang, protected, rooted, financing, implications, indo, wins,
# Nearest to and: itself, reforms, forster, cd, workings, say, debated, spell,
# Nearest to in: wilbur, telecom, fraternities, zhao, philosophers, peace, fewer, funnel,
# Nearest to two: zero, nursia, giovanni, indicator, faces, kathleen, curbing, emperor,
# Nearest to file: lancastrian, suki, gcc, galaxies, choral, metering, snapped, username,
# Nearest to bbc: owing, fine, dukes, dock, drastic, wintour, monitors, signed,
# Nearest to existence: ppr, brute, gyula, shipment, egyptian, ban, kim, retroviruses,
# Nearest to heavy: noord, maclaine, airport, aegean, banknote, lobito, reorganised, judicial,
# Nearest to animals: purchase, painters, remarkably, baptists, contact, inventory, izmir, komo,
# Nearest to units: instrumental, lament, disambiguation, patterns, planning, encouraged, inventiveness, yankee,
# Nearest to universe: consanguinity, misconception, extract, proposed, questionnaire, call, forms, heiland,
# Nearest to know: conviction, habitual, turnout, conformity, combinations, ingrained, undercover, hector,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7662 0.1138 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7557 0.1121 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7164 0.1142 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7081 0.1136 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7409 0.1142 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7149 0.1120 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7114 0.1147 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7400 0.1145 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7117 0.1132 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6840 0.1142 sec/batch
# Nearest to of: fake, surplus, beaten, takeover, henry, preceding, inspirational, expansion,
# Nearest to one: george, laureate, realised, d, footballer, nine, ailing, styled,
# Nearest to the: coroner, billed, bolivian, holman, holding, innumerable, pakistan, voiceover,
# Nearest to to: messengers, squire, megabats, pronouncing, bh, elaborations, covers, supplied,
# Nearest to a: sectarian, unappealing, rooted, raison, sprang, grantham, implications, protected,
# Nearest to and: itself, reforms, praises, forster, organizing, workings, cd, enhance,
# Nearest to in: wilbur, zhao, telecom, peace, funnel, characterize, philosophers, fraternities,
# Nearest to two: zero, kathleen, nursia, giovanni, curbing, distraught, maurice, eamon,
# Nearest to file: suki, lancastrian, metering, gcc, choral, galaxies, snapped, username,
# Nearest to bbc: dock, fine, wintour, owing, dukes, catered, gunman, signed,
# Nearest to existence: ppr, gyula, brute, shipment, kim, jamais, egyptian, baur,
# Nearest to heavy: maclaine, noord, aegean, reorganised, often, lobito, banknote, airport,
# Nearest to animals: baptists, purchase, contact, painters, izmir, remarkably, axiomatization, inventory,
# Nearest to units: instrumental, lament, disambiguation, patterns, planning, inventiveness, encouraged, vishnu,
# Nearest to universe: consanguinity, misconception, proposed, extract, xaver, questionnaire, forms, dah,
# Nearest to know: conviction, habitual, turnout, ingrained, conformity, undercover, imitated, combinations,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6876 0.1147 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6615 0.1124 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6207 0.1156 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6371 0.1146 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6424 0.1135 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6362 0.1122 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6037 0.0843 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5827 0.1146 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5221 0.1140 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5175 0.1119 sec/batch
# Nearest to of: fake, beaten, surplus, plantagenet, henry, muslims, takeover, sahel,
# Nearest to one: d, george, laureate, footballer, nine, inventor, augustin, pitt,
# Nearest to the: coroner, billed, bolivian, holman, bohr, holding, innumerable, pakistan,
# Nearest to to: messengers, squire, megabats, pronouncing, elaborations, than, bh, tunnels,
# Nearest to a: sectarian, unappealing, grantham, rooted, pessimism, deflationary, perform, sprang,
# Nearest to and: itself, reforms, workings, lays, gamers, cd, praises, wembley,
# Nearest to in: zhao, telecom, wilbur, fraternities, congresses, characterize, summation, funnel,
# Nearest to two: zero, maurice, kathleen, nursia, painter, distraught, curbing, giovanni,
# Nearest to file: suki, gcc, metering, lancastrian, choral, galaxies, snapped, username,
# Nearest to bbc: dock, wintour, fine, catered, dukes, owing, joiner, gunman,
# Nearest to existence: ppr, gyula, brute, fasa, baur, jamais, primaries, geneticists,
# Nearest to heavy: noord, maclaine, reorganised, lobito, aegean, airport, banknote, telemark,
# Nearest to animals: baptists, purchase, contact, inventory, remarkably, painters, axiomatization, izmir,
# Nearest to units: instrumental, lament, disambiguation, patterns, planning, given, herut, stevenson,
# Nearest to universe: consanguinity, xaver, proposed, forms, misconception, extract, dah, questionnaire,
# Nearest to know: conviction, habitual, ingrained, turnout, hanssen, undercover, conformity, imitated,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4907 0.1147 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5044 0.1137 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4924 0.1149 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5171 0.1137 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4801 0.1137 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5074 0.1143 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4666 0.1150 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4044 0.1154 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4195 0.1168 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4280 0.1162 sec/batch
# Nearest to of: fake, surplus, muslims, decidable, prophet, beaten, agree, antiderivatives,
# Nearest to one: d, footballer, george, lacquer, nine, concord, laureate, stative,
# Nearest to the: billed, coroner, innumerable, criterion, bolivian, bohr, holding, cayley,
# Nearest to to: messengers, megabats, than, instead, squire, elaborations, dormitory, properties,
# Nearest to a: sectarian, unappealing, cards, grantham, perform, pessimism, rooted, carnivorous,
# Nearest to and: itself, reforms, workings, enhance, scouring, cd, lays, maelstrom,
# Nearest to in: zhao, telecom, fraternities, characterize, congresses, summation, glee, staunchly,
# Nearest to two: zero, nursia, est, gigs, curbing, distraught, indicator, kathleen,
# Nearest to file: metering, gcc, suki, galaxies, lancastrian, choral, teletype, snapped,
# Nearest to bbc: fine, dock, gunman, wintour, catered, joiner, ellesmere, alexanderplatz,
# Nearest to existence: ppr, gyula, brute, fasa, baur, geneticists, mistreated, nextstep,
# Nearest to heavy: noord, maclaine, reorganised, airport, aegean, lobito, telemark, receivers,
# Nearest to animals: baptists, contact, purchase, inventory, remarkably, painters, rspca, izmir,
# Nearest to units: instrumental, disambiguation, lament, patterns, herut, planning, roscommon, acetylcholine,
# Nearest to universe: consanguinity, forms, proposed, xaver, misconception, extract, questionnaire, call,
# Nearest to know: conviction, habitual, hanssen, ingrained, turnout, motion, conformity, imitated,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4278 0.1158 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3979 0.1143 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4458 0.1145 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3882 0.1152 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4073 0.1145 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4035 0.1132 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3877 0.1134 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3900 0.1146 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4155 0.1132 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3594 0.1130 sec/batch
# Nearest to of: fake, decidable, surplus, plantagenet, imposition, the, antiderivatives, called,
# Nearest to one: footballer, laureate, d, nine, george, five, concord, mathematician,
# Nearest to the: coroner, holding, billed, bolivian, bohr, criterion, cayley, innumerable,
# Nearest to to: messengers, megabats, squire, defaults, than, elaborations, instead, tunnels,
# Nearest to a: sectarian, unappealing, deflationary, perform, thighs, grantham, raison, pessimism,
# Nearest to and: itself, scouring, maelstrom, workings, lays, praises, reforms, skins,
# Nearest to in: congresses, fraternities, telecom, zhao, epicurean, peace, staunchly, disastrous,
# Nearest to two: zero, nursia, three, four, gigs, est, curbing, six,
# Nearest to file: metering, gcc, suki, galaxies, lancastrian, choral, servers, snapped,
# Nearest to bbc: fine, catered, wintour, joiner, dock, gunman, sitcoms, pla,
# Nearest to existence: ppr, brute, baur, gyula, geneticists, fasa, cosmological, individuals,
# Nearest to heavy: noord, maclaine, reorganised, glyceraldehyde, receivers, airport, aegean, thracian,
# Nearest to animals: baptists, contact, purchase, inventory, izmir, remarkably, rspca, komo,
# Nearest to units: disambiguation, instrumental, patterns, lament, planning, herut, tailing, dma,
# Nearest to universe: consanguinity, proposed, forms, misconception, xaver, questionnaire, extract, call,
# Nearest to know: conviction, hanssen, habitual, imitated, turnout, ingrained, motion, conformity,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3900 0.1137 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3674 0.1123 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3531 0.1129 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3933 0.1131 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3923 0.1134 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3534 0.1135 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3658 0.1131 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4044 0.1141 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3382 0.1147 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3322 0.1154 sec/batch
# Nearest to of: the, varphi, imposition, surplus, plantagenet, fake, muslims, prophet,
# Nearest to one: nine, five, zero, concord, six, na, footballer, belgrade,
# Nearest to the: of, coroner, billed, bolivian, this, holding, pakistan, between,
# Nearest to to: messengers, instead, than, defaults, incredibly, megabats, conduct, squire,
# Nearest to a: unappealing, sectarian, thighs, deflationary, pessimism, s, raison, perform,
# Nearest to and: itself, scouring, reforms, elsewhere, enhance, workings, resurrecting, lays,
# Nearest to in: congresses, fraternities, staunchly, other, zhao, peace, annexed, telecom,
# Nearest to two: zero, four, three, nursia, six, eight, five, preprint,
# Nearest to file: metering, gcc, suki, servers, galaxies, requests, realtime, teletype,
# Nearest to bbc: wintour, fine, sitcoms, catered, joiner, gunman, dock, pla,
# Nearest to existence: brute, cosmological, baur, ppr, fasa, gyula, geneticists, mnemosyne,
# Nearest to heavy: noord, maclaine, reorganised, bharatiya, receivers, hada, glyceraldehyde, seaports,
# Nearest to animals: baptists, contact, blood, inventory, komo, proximal, izmir, remarkably,
# Nearest to units: disambiguation, instrumental, planning, herut, lament, tailing, patterns, transferring,
# Nearest to universe: proposed, forms, consanguinity, misconception, xaver, questionnaire, extract, dah,
# Nearest to know: conviction, habitual, hanssen, motion, imitated, ingrained, permeates, conformity,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3069 0.1160 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3007 0.1133 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3793 0.1151 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3614 0.1138 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3656 0.1162 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2861 0.1134 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3076 0.1127 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3612 0.1128 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2325 0.1141 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3021 0.1142 sec/batch
# Nearest to of: the, varphi, migration, engenders, surplus, fake, plantagenet, imposition,
# Nearest to one: nine, zero, five, eight, six, d, footballer, laureate,
# Nearest to the: coroner, of, billed, bolivian, holding, this, confined, policing,
# Nearest to to: than, conduct, messengers, instead, megabats, incredibly, defaults, squire,
# Nearest to a: unappealing, sectarian, thighs, deflationary, s, sprang, perform, grantham,
# Nearest to and: enhance, reforms, itself, maelstrom, lays, togo, elsewhere, infinitesimally,
# Nearest to in: congresses, fraternities, annexed, dispatched, characterize, staunchly, peace, zhao,
# Nearest to two: zero, four, three, six, five, eight, seven, one,
# Nearest to file: gcc, suki, metering, servers, requests, realtime, galaxies, codebase,
# Nearest to bbc: wintour, joiner, fine, sitcoms, catered, gunman, dock, pla,
# Nearest to existence: brute, baur, cosmological, fasa, mnemosyne, ppr, gyula, geneticists,
# Nearest to heavy: noord, maclaine, reorganised, bharatiya, glyceraldehyde, airport, receivers, seaports,
# Nearest to animals: baptists, contact, blood, inventory, izmir, tremors, proximal, remarkably,
# Nearest to units: disambiguation, herut, instrumental, planning, acetylcholine, lament, tailing, artillery,
# Nearest to universe: proposed, consanguinity, forms, dah, questionnaire, xaver, misconception, reader,
# Nearest to know: conviction, habitual, hanssen, undercover, imitated, ingrained, permeates, motion,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3069 0.1146 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2783 0.1131 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3379 0.0558 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2317 0.1136 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2368 0.1134 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2050 0.1139 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2095 0.1126 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2086 0.1132 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2216 0.1151 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1460 0.1124 sec/batch
# Nearest to of: the, called, decidable, variances, prophet, varphi, imposition, fake,
# Nearest to one: nine, five, zero, six, eight, two, three, d,
# Nearest to the: bolivian, of, holding, deflagration, mountains, this, billed, cayley,
# Nearest to to: than, incredibly, megabats, instead, conduct, messengers, defaults, looters,
# Nearest to a: unappealing, sectarian, thighs, wins, deflationary, grantham, s, perform,
# Nearest to and: enhance, reforms, scouring, itself, elsewhere, infinitesimally, togo, belize,
# Nearest to in: congresses, annexed, staunchly, akita, rhazes, peace, dispatched, characterize,
# Nearest to two: zero, three, four, six, five, eight, seven, one,
# Nearest to file: suki, gcc, metering, servers, requests, realtime, codebase, galaxies,
# Nearest to bbc: fine, wintour, joiner, catered, sitcoms, pla, gunman, dock,
# Nearest to existence: cosmological, brute, fasa, mnemosyne, baur, ppr, humanistic, principle,
# Nearest to heavy: noord, reorganised, maclaine, bharatiya, glyceraldehyde, receivers, airport, transatlantic,
# Nearest to animals: baptists, contact, blood, mammalian, tremors, proximal, chlorophyll, inventory,
# Nearest to units: disambiguation, planning, herut, artillery, acetylcholine, borderland, barreled, instrumental,
# Nearest to universe: proposed, consanguinity, forms, questionnaire, xaver, dah, misconception, intelligent,
# Nearest to know: conviction, habitual, hanssen, imitated, undercover, ingrained, permeates, conformity,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2406 0.1152 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2464 0.1146 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2157 0.1146 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1329 0.1157 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1723 0.1160 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1581 0.1149 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1736 0.1145 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1660 0.1140 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2250 0.1156 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1677 0.1149 sec/batch
# Nearest to of: called, decidable, the, variances, fake, varphi, prophet, astrolabe,
# Nearest to one: zero, nine, six, five, eight, two, three, na,
# Nearest to the: holding, this, of, cayley, bolivian, otomo, undertaken, billed,
# Nearest to to: than, megabats, instead, incredibly, looters, defaults, properties, messengers,
# Nearest to a: unappealing, thighs, sectarian, deflationary, tabular, perform, s, pneumococcus,
# Nearest to and: enhance, itself, scouring, infinitesimally, cd, maelstrom, skins, gamers,
# Nearest to in: akita, characterize, staunchly, tramway, rhazes, fraternities, annexed, keeshonden,
# Nearest to two: zero, three, four, six, five, seven, one, eight,
# Nearest to file: suki, metering, gcc, requests, realtime, servers, files, codebase,
# Nearest to bbc: fine, joiner, sitcoms, wintour, catered, dock, cis, drastic,
# Nearest to existence: cosmological, brute, principle, baur, humanistic, fasa, ppr, mnemosyne,
# Nearest to heavy: noord, bharatiya, maclaine, landing, glyceraldehyde, reorganised, transatlantic, ostia,
# Nearest to animals: baptists, contact, blood, tremors, mammalian, chlorophyll, inventory, primates,
# Nearest to units: planning, disambiguation, artillery, herut, barreled, acetylcholine, dma, forces,
# Nearest to universe: proposed, consanguinity, forms, xaver, questionnaire, dah, intelligent, mappings,
# Nearest to know: conviction, habitual, hanssen, undercover, imitated, ingrained, permeates, motion,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1659 0.1148 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2396 0.1143 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2038 0.1128 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1588 0.1153 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1976 0.1140 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2154 0.1141 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1977 0.1131 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1508 0.1124 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1351 0.1138 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1772 0.1120 sec/batch
# Nearest to of: the, called, decidable, ricimer, varphi, only, substantiated, svinhufvud,
# Nearest to one: nine, zero, five, six, eight, two, three, est,
# Nearest to the: of, this, holding, otomo, bolivian, alludes, therefore, undertaken,
# Nearest to to: megabats, than, incredibly, instead, defaults, conduct, properties, looters,
# Nearest to a: unappealing, thighs, deflationary, s, sectarian, tabular, grantham, wins,
# Nearest to and: reforms, togo, enhance, itself, markets, scouring, fta, infinitesimally,
# Nearest to in: fraternities, rhazes, staunchly, keeshonden, congresses, other, characterize, agena,
# Nearest to two: zero, three, four, six, five, one, eight, seven,
# Nearest to file: gcc, suki, metering, requests, realtime, servers, files, teletype,
# Nearest to bbc: sitcoms, fine, joiner, wintour, catered, dock, ibu, pla,
# Nearest to existence: baur, cosmological, principle, brute, mnemosyne, ppr, fasa, humanistic,
# Nearest to heavy: noord, glyceraldehyde, maclaine, bharatiya, landing, reorganised, transatlantic, ostia,
# Nearest to animals: baptists, contact, mammalian, tremors, primates, blood, chlorophyll, diversity,
# Nearest to units: disambiguation, planning, artillery, herut, barreled, acetylcholine, transferring, tailing,
# Nearest to universe: proposed, consanguinity, forms, questionnaire, intelligent, dah, xaver, cosmological,
# Nearest to know: conviction, habitual, undercover, imitated, hanssen, sarcastic, permeates, wonderful,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2026 0.1138 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1466 0.1131 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2017 0.1129 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2001 0.1127 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1361 0.1151 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1366 0.1151 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1809 0.1148 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0890 0.1148 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2120 0.1138 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2394 0.1143 sec/batch
# Nearest to of: the, ricimer, called, henry, prophet, eight, adversus, svinhufvud,
# Nearest to one: nine, five, six, zero, eight, two, three, four,
# Nearest to the: of, this, bolivian, beheaded, andrewes, otomo, transliterated, holding,
# Nearest to to: incredibly, conduct, looters, instead, suva, megabats, defaults, than,
# Nearest to a: s, sectarian, thighs, unappealing, lactantius, whirling, playwright, grantham,
# Nearest to and: reforms, togo, enhance, neruda, forster, fta, hashemite, cosmologists,
# Nearest to in: staunchly, rhazes, annexed, fraternities, keeshonden, peace, tallahassee, the,
# Nearest to two: zero, three, four, six, five, one, eight, seven,
# Nearest to file: gcc, suki, requests, metering, realtime, servers, servlet, document,
# Nearest to bbc: joiner, sitcoms, fine, wintour, ibu, catered, pla, ax,
# Nearest to existence: baur, cosmological, mnemosyne, fasa, ppr, principle, brute, gyula,
# Nearest to heavy: noord, maclaine, glyceraldehyde, reorganised, bharatiya, ostia, intercalary, landing,
# Nearest to animals: baptists, contact, primates, mammalian, tremors, inventory, chlorophyll, blood,
# Nearest to units: disambiguation, artillery, planning, herut, barreled, forces, disarray, borderland,
# Nearest to universe: proposed, consanguinity, questionnaire, forms, dah, intelligent, xaver, cosmological,
# Nearest to know: conviction, habitual, undercover, hanssen, sarcastic, permeates, imitated, wonderful,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2086 0.1154 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1328 0.1144 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1413 0.1137 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1528 0.1132 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0617 0.1142 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1265 0.1142 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1208 0.1135 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1522 0.1128 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1699 0.0257 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1294 0.1134 sec/batch
# Nearest to of: the, called, svinhufvud, ricimer, henry, communaut, variances, varphi,
# Nearest to one: nine, zero, five, six, two, eight, three, four,
# Nearest to the: of, this, in, bolivian, protea, maxima, andrewes, otomo,
# Nearest to to: than, megabats, suva, incredibly, conduct, instead, defaults, looters,
# Nearest to a: thighs, unappealing, s, sectarian, it, have, deflationary, to,
# Nearest to and: togo, enhance, infinitesimally, as, confusion, reforms, combatting, markets,
# Nearest to in: the, characterize, staunchly, thessalian, tallahassee, rhazes, annexed, other,
# Nearest to two: zero, three, four, six, five, one, eight, seven,
# Nearest to file: gcc, suki, metering, requests, realtime, servers, document, subroutines,
# Nearest to bbc: joiner, fine, sitcoms, ibu, wintour, catered, cis, pla,
# Nearest to existence: cosmological, baur, universe, gyula, mnemosyne, principle, humanistic, ppr,
# Nearest to heavy: noord, bharatiya, reorganised, intercalary, maclaine, ostia, glyceraldehyde, transatlantic,
# Nearest to animals: baptists, mammalian, primates, contact, chlorophyll, inventory, suggests, tremors,
# Nearest to units: artillery, planning, disambiguation, barreled, herut, forces, disarray, allied,
# Nearest to universe: proposed, consanguinity, forms, cosmological, existence, dah, intelligent, questionnaire,
# Nearest to know: conviction, undercover, habitual, sarcastic, hanssen, articulate, wonderful, tenths,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0839 0.1158 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0541 0.1122 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1076 0.1127 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0829 0.1132 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0877 0.1136 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0137 0.1143 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0725 0.1135 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0906 0.1141 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1188 0.1147 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0154 0.1142 sec/batch
# Nearest to of: the, called, variances, tongues, only, see, varphi, henry,
# Nearest to one: nine, zero, five, six, two, three, eight, four,
# Nearest to the: of, in, this, martians, bolivian, holding, dragged, to,
# Nearest to to: than, incredibly, instead, conduct, defaults, suva, looters, they,
# Nearest to a: unappealing, thighs, perform, it, sectarian, s, undirected, to,
# Nearest to and: enhance, togo, infinitesimally, as, itself, cosmologists, scouring, gamers,
# Nearest to in: the, characterize, staunchly, akita, tallahassee, disastrous, other, annexed,
# Nearest to two: zero, three, four, six, five, one, seven, eight,
# Nearest to file: suki, gcc, requests, metering, realtime, servers, subroutines, teletype,
# Nearest to bbc: joiner, sitcoms, fine, ibu, december, wintour, cis, catered,
# Nearest to existence: cosmological, baur, universe, principle, gyula, fasa, mnemosyne, ppr,
# Nearest to heavy: noord, ostia, intercalary, bharatiya, reorganised, glyceraldehyde, maclaine, telemark,
# Nearest to animals: baptists, mammalian, primates, inventory, rspca, contact, chlorophyll, calves,
# Nearest to units: disambiguation, planning, barreled, artillery, herut, disarray, forces, enables,
# Nearest to universe: proposed, cosmological, intelligent, forms, mappings, questionnaire, consanguinity, existence,
# Nearest to know: conviction, habitual, undercover, sarcastic, hanssen, articulate, socrates, wonderful,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0228 0.1167 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0146 0.1154 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0096 0.1147 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0633 0.1149 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0421 0.1143 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0713 0.1164 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0746 0.1142 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0741 0.1135 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0741 0.1137 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0477 0.1146 sec/batch
# Nearest to of: the, called, only, see, decidable, in, cinematographers, variances,
# Nearest to one: zero, nine, five, six, two, three, eight, four,
# Nearest to the: of, this, in, martians, maxima, therefore, its, protea,
# Nearest to to: than, instead, defaults, incredibly, conduct, looters, megabats, conditions,
# Nearest to a: unappealing, undirected, tabular, deflationary, lz, s, lactantius, perform,
# Nearest to and: enhance, as, cosmologists, infinitesimally, togo, itself, non, scouring,
# Nearest to in: the, characterize, other, akita, of, tallahassee, hilbert, fraternities,
# Nearest to two: zero, three, four, five, six, one, seven, eight,
# Nearest to file: gcc, suki, requests, metering, realtime, subroutines, files, document,
# Nearest to bbc: sitcoms, joiner, december, ibu, fine, focused, magazine, wintour,
# Nearest to existence: cosmological, universe, baur, principle, fasa, ppr, mnemosyne, ufo,
# Nearest to heavy: bharatiya, glyceraldehyde, noord, ostia, nascent, treacherous, rifled, reorganised,
# Nearest to animals: baptists, mammalian, primates, inventory, calves, rspca, contact, axiomatization,
# Nearest to units: planning, disambiguation, barreled, artillery, forces, herut, disarray, acetylcholine,
# Nearest to universe: proposed, consanguinity, cosmological, existence, questionnaire, intelligent, forms, xaver,
# Nearest to know: conviction, undercover, habitual, sarcastic, hanssen, wonderful, turnout, gutnish,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0665 0.1162 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0959 0.1144 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0778 0.1141 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0626 0.1131 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0876 0.1137 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0648 0.1129 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0761 0.1137 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0490 0.1138 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0605 0.1145 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0745 0.1129 sec/batch
# Nearest to of: the, called, henry, eight, in, five, ricimer, svinhufvud,
# Nearest to one: zero, nine, five, two, six, three, eight, four,
# Nearest to the: of, in, this, mok, martians, to, maxima, cyrene,
# Nearest to to: in, than, the, instead, looters, they, conduct, by,
# Nearest to a: unappealing, s, sectarian, lactantius, deflationary, tabular, undirected, to,
# Nearest to and: togo, as, reforms, enhance, the, kearney, non, in,
# Nearest to in: the, to, annexed, after, rhazes, of, disastrous, fraternities,
# Nearest to two: zero, three, four, five, six, one, seven, eight,
# Nearest to file: gcc, suki, requests, metering, realtime, filename, files, subroutines,
# Nearest to bbc: sitcoms, joiner, december, ibu, fine, wintour, magazine, catered,
# Nearest to existence: cosmological, universe, principle, baur, phraseology, fasa, mnemosyne, metaphysician,
# Nearest to heavy: maclaine, nascent, intercalary, punk, ostia, glyceraldehyde, bharatiya, mistreatment,
# Nearest to animals: baptists, calves, primates, mammalian, nests, rspca, inventory, contact,
# Nearest to units: disambiguation, planning, barreled, disarray, forces, herut, artillery, acetylcholine,
# Nearest to universe: proposed, cosmological, existence, consanguinity, questionnaire, intelligent, forms, mappings,
# Nearest to know: conviction, undercover, habitual, sarcastic, hanssen, wonderful, seem, turnout,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0480 0.1165 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0132 0.1141 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0574 0.1157 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0731 0.1142 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0768 0.1145 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1205 0.1137 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1322 0.1140 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0492 0.1131 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0392 0.1122 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0378 0.1133 sec/batch
# Nearest to of: the, called, in, henry, eight, see, nmr, list,
# Nearest to one: zero, nine, five, two, six, three, eight, four,
# Nearest to the: of, in, this, maxima, martians, mok, on, its,
# Nearest to to: instead, they, than, tunnels, looters, hurd, is, incredibly,
# Nearest to a: unappealing, s, deflationary, from, undirected, to, perform, tabular,
# Nearest to and: togo, infinitesimally, enhance, as, sufficiently, confusion, mayfair, brains,
# Nearest to in: the, of, after, during, fraternities, to, characterize, congresses,
# Nearest to two: zero, three, five, four, six, one, seven, eight,
# Nearest to file: suki, gcc, requests, metering, realtime, subroutines, filename, files,
# Nearest to bbc: december, joiner, sitcoms, ibu, fine, wintour, holiday, ax,
# Nearest to existence: cosmological, baur, universe, principle, mnemosyne, phraseology, fasa, ufo,
# Nearest to heavy: nascent, treacherous, mistreatment, ostia, punk, maclaine, intercalary, telemark,
# Nearest to animals: baptists, calves, primates, rspca, inventory, axiomatization, mammalian, contact,
# Nearest to units: disambiguation, planning, barreled, herut, transferring, forces, disarray, unit,
# Nearest to universe: proposed, cosmological, questionnaire, existence, consanguinity, intelligent, forms, dah,
# Nearest to know: conviction, undercover, habitual, sarcastic, wonderful, ibelin, you, hanssen,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9563 0.1159 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0551 0.1144 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0503 0.1136 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0218 0.1131 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0739 0.1143 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0397 0.1088 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9970 0.1132 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9554 0.1131 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0059 0.1121 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9888 0.1128 sec/batch
# Nearest to of: the, called, see, henry, eight, in, ricimer, variances,
# Nearest to one: nine, five, zero, two, six, three, eight, four,
# Nearest to the: of, in, this, martians, maxima, mok, biodiesel, an,
# Nearest to to: than, they, incredibly, by, tunnels, instead, a, megabats,
# Nearest to a: unappealing, undirected, from, s, deflationary, to, tabular, arabs,
# Nearest to and: infinitesimally, togo, as, sufficiently, enhance, well, confusion, exoteric,
# Nearest to in: the, after, characterize, of, rhazes, fraternities, tallahassee, hilbert,
# Nearest to two: zero, three, four, five, one, six, seven, eight,
# Nearest to file: gcc, suki, requests, metering, realtime, subroutines, files, filename,
# Nearest to bbc: december, sitcoms, joiner, ibu, holiday, fine, wintour, ax,
# Nearest to existence: cosmological, universe, principle, baur, mnemosyne, phraseology, fasa, ufo,
# Nearest to heavy: nascent, treacherous, mistreatment, telemark, ostia, bharatiya, intercalary, punk,
# Nearest to animals: calves, primates, baptists, rspca, axiomatization, inventory, nests, suggests,
# Nearest to units: disambiguation, barreled, planning, unit, forces, transferring, enables, herut,
# Nearest to universe: proposed, cosmological, existence, questionnaire, intelligent, forms, consanguinity, mappings,
# Nearest to know: conviction, habitual, undercover, sarcastic, wonderful, you, ibelin, tenths,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9842 0.1141 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9233 0.1134 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9933 0.1135 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9766 0.1133 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0235 0.1147 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0095 0.1138 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9179 0.1153 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9570 0.1154 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9226 0.1164 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9918 0.1147 sec/batch
# Nearest to of: the, called, in, see, and, list, only, five,
# Nearest to one: zero, five, two, nine, three, six, four, eight,
# Nearest to the: of, in, this, martians, to, a, an, which,
# Nearest to to: they, than, instead, conditions, is, the, a, by,
# Nearest to a: undirected, unappealing, from, the, to, which, number, permutations,
# Nearest to and: as, enhance, infinitesimally, over, of, togo, non, in,
# Nearest to in: the, of, other, after, to, mitosis, characterize, and,
# Nearest to two: zero, three, four, five, one, six, seven, eight,
# Nearest to file: suki, gcc, requests, metering, subroutines, realtime, files, filename,
# Nearest to bbc: december, sitcoms, joiner, ibu, fine, holiday, magazine, ax,
# Nearest to existence: cosmological, universe, principle, baur, ufo, mnemosyne, fasa, clashes,
# Nearest to heavy: nascent, treacherous, rifled, mistreatment, telemark, glyceraldehyde, noord, reorganised,
# Nearest to animals: rspca, calves, primates, axiomatization, baptists, inventory, chlorophyll, crayfish,
# Nearest to units: disambiguation, planning, barreled, unit, forces, transferring, enables, counties,
# Nearest to universe: cosmological, proposed, existence, questionnaire, consanguinity, intelligent, abundances, proton,
# Nearest to know: conviction, habitual, undercover, you, sarcastic, wonderful, ibelin, wrong,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9887 0.1155 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9967 0.1154 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9961 0.1142 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0030 0.1127 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0179 0.1145 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9654 0.1145 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9895 0.1142 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9881 0.1153 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9962 0.1152 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9788 0.1142 sec/batch
# Nearest to of: the, called, see, in, title, cinematographers, henry, a,
# Nearest to one: nine, zero, five, two, three, six, four, eight,
# Nearest to the: of, in, this, to, an, maxima, a, martians,
# Nearest to to: instead, by, the, they, in, is, conditions, defaults,
# Nearest to a: unappealing, which, the, s, from, undirected, of, lactantius,
# Nearest to and: as, togo, enhance, over, non, the, infinitesimally, in,
# Nearest to in: the, of, after, to, other, akita, which, mitosis,
# Nearest to two: zero, three, four, one, five, six, seven, eight,
# Nearest to file: suki, requests, gcc, subroutines, metering, realtime, files, filename,
# Nearest to bbc: december, sitcoms, joiner, ibu, fine, holiday, magazine, wintour,
# Nearest to existence: cosmological, universe, principle, baur, ufo, phraseology, fasa, mnemosyne,
# Nearest to heavy: nascent, treacherous, glyceraldehyde, rifled, telemark, maclaine, cause, toluene,
# Nearest to animals: calves, primates, rspca, axiomatization, baptists, crayfish, chlorophyll, inventory,
# Nearest to units: disambiguation, planning, unit, forces, barreled, counties, transferring, enables,
# Nearest to universe: proposed, cosmological, existence, questionnaire, consanguinity, intelligent, proton, forms,
# Nearest to know: conviction, undercover, habitual, you, sarcastic, ibelin, wonderful, wrong,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9796 0.1144 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9928 0.1137 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9992 0.1126 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0079 0.1126 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0085 0.1140 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9927 0.1126 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0059 0.1154 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9450 0.1152 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9405 0.1136 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0277 0.1153 sec/batch
# Nearest to of: the, in, see, called, title, five, list, and,
# Nearest to one: nine, five, zero, two, three, six, four, eight,
# Nearest to the: in, of, this, to, maxima, an, which, on,
# Nearest to to: by, they, in, the, instead, for, conditions, is,
# Nearest to a: from, which, unappealing, the, s, to, tabular, undirected,
# Nearest to and: togo, as, over, non, of, the, enhance, in,
# Nearest to in: the, after, of, to, during, other, and, by,
# Nearest to two: zero, three, four, five, one, six, seven, eight,
# Nearest to file: suki, gcc, requests, realtime, metering, subroutines, filename, files,
# Nearest to bbc: december, sitcoms, joiner, ibu, holiday, fine, days, wintour,
# Nearest to existence: cosmological, universe, principle, baur, gyula, phraseology, clashes, mnemosyne,
# Nearest to heavy: nascent, treacherous, punk, glyceraldehyde, maclaine, telemark, mistreatment, thracian,
# Nearest to animals: calves, rspca, primates, axiomatization, baptists, crayfish, inventory, suggests,
# Nearest to units: disambiguation, unit, forces, planning, counties, barreled, transferring, herut,
# Nearest to universe: proposed, cosmological, existence, questionnaire, intelligent, consanguinity, proton, abundances,
# Nearest to know: conviction, habitual, undercover, you, wonderful, ibelin, sarcastic, wrong,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9668 0.1138 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0825 0.1145 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0593 0.1136 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0158 0.1142 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9314 0.1140 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9688 0.1130 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9597 0.1136 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9243 0.1141 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9917 0.1168 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9624 0.1132 sec/batch
# Nearest to of: the, in, see, and, a, called, list, eight,
# Nearest to one: five, nine, zero, two, three, six, eight, four,
# Nearest to the: of, in, this, maxima, to, a, an, and,
# Nearest to to: they, a, by, in, than, the, instead, for,
# Nearest to a: from, to, which, of, the, s, unappealing, in,
# ...
# Nearest to file: files, suki, realtime, draw, username, metering, subroutines, filename,
# Nearest to bbc: december, news, ibu, uktv, fine, days, sitcoms, remaining,
# Nearest to existence: universe, principle, ufo, phraseology, ary, cosmological, baur, mnemosyne,
# Nearest to heavy: telemark, thracian, treacherous, heaviest, motown, cmf, strengthened, bharatiya,
# Nearest to animals: rspca, pigs, axiomatization, herm, peano, calves, cryptology, primates,
# Nearest to units: unit, counties, regiment, si, forces, disambiguation, barreled, wintered,
# Nearest to universe: cosmological, existence, proposed, efe, intelligent, cosmology, abundances, lensing,
# Nearest to know: wrong, conviction, you, undercover, why, ibelin, didn, habitual,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8500 0.1152 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7696 0.1143 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8334 0.1153 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7664 0.1151 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8028 0.1150 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8434 0.1158 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8656 0.1147 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8381 0.1142 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8872 0.1135 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9201 0.1121 sec/batch
# Nearest to of: the, in, and, a, see, one, as, by,
# Nearest to one: five, two, four, six, three, nine, zero, eight,
# Nearest to the: in, of, a, this, and, first, by, which,
# Nearest to to: they, the, and, in, a, by, for, from,
# Nearest to a: the, in, of, which, from, and, to, s,
# Nearest to and: in, of, the, as, a, with, to, by,
# Nearest to in: the, of, and, a, after, by, to, first,
# Nearest to two: zero, three, four, one, five, six, seven, nine,
# Nearest to file: files, draw, suki, subroutines, realtime, username, metering, filename,
# Nearest to bbc: december, news, days, ibu, uktv, day, fine, sitcoms,
# Nearest to existence: universe, principle, ary, phraseology, cosmological, ufo, universals, concept,
# Nearest to heavy: telemark, axopods, heaviest, cmf, infarction, cause, thracian, treacherous,
# Nearest to animals: pigs, rspca, axiomatization, herm, calves, crayfish, peano, hexokinase,
# Nearest to units: unit, counties, regiment, si, forces, disambiguation, wintered, disarray,
# Nearest to universe: cosmological, existence, proposed, efe, cosmology, intelligent, warrior, fictional,
# Nearest to know: wrong, conviction, you, undercover, why, didn, something, ve,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8283 0.1156 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8791 0.1136 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8274 0.1145 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8532 0.1142 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8832 0.1136 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8863 0.1129 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8501 0.1137 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8451 0.1130 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8776 0.1134 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8632 0.1161 sec/batch
# Nearest to of: the, in, and, a, by, one, see, from,
# Nearest to one: five, two, four, three, nine, zero, six, eight,
# Nearest to the: in, of, this, a, and, by, which, an,
# Nearest to to: the, and, they, in, a, by, for, from,
# Nearest to a: the, which, of, in, from, and, to, an,
# Nearest to and: in, of, the, with, by, to, as, a,
# Nearest to in: the, of, and, a, by, which, to, after,
# Nearest to two: zero, three, four, one, five, six, seven, nine,
# Nearest to file: files, draw, suki, filename, realtime, subroutines, username, metering,
# Nearest to bbc: december, news, ibu, days, uktv, fine, sitcoms, day,
# Nearest to existence: universe, principle, ary, cosmological, phraseology, baur, exists, universals,
# Nearest to heavy: telemark, thracian, infarction, axopods, decaying, cmf, heaviest, treacherous,
# Nearest to animals: rspca, pigs, herm, axiomatization, calves, peano, primates, crayfish,
# Nearest to units: unit, counties, regiment, si, disambiguation, wintered, forces, disarray,
# Nearest to universe: cosmological, existence, proposed, intelligent, efe, cosmology, warrior, fictional,
# Nearest to know: wrong, conviction, undercover, you, didn, why, ibelin, something,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8480 0.1144 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8066 0.1140 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8455 0.1159 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8313 0.1150 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9080 0.1152 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8347 0.1142 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9599 0.1120 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8886 0.1130 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8901 0.1138 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8239 0.1126 sec/batch
# Nearest to of: the, in, and, a, from, one, by, see,
# Nearest to one: two, five, three, four, nine, zero, six, eight,
# Nearest to the: in, of, a, this, by, an, and, on,
# Nearest to to: the, in, they, a, for, from, and, by,
# Nearest to a: the, from, in, of, which, s, to, and,
# Nearest to and: in, of, with, the, by, as, one, nine,
# Nearest to in: the, of, and, a, after, by, to, with,
# Nearest to two: zero, three, five, one, four, six, seven, nine,
# Nearest to file: files, suki, draw, filename, realtime, username, rev, subroutines,
# Nearest to bbc: december, news, day, ibu, days, remaining, uktv, fine,
# Nearest to existence: universe, principle, cosmological, baur, universals, phraseology, ufo, ary,
# Nearest to heavy: thracian, decaying, treacherous, telemark, cause, motown, significant, strengthened,
# Nearest to animals: pigs, rspca, herm, axiomatization, peano, crayfish, primates, steward,
# Nearest to units: unit, counties, si, regiment, forces, wintered, disambiguation, metrology,
# Nearest to universe: cosmological, existence, proposed, intelligent, efe, cosmology, warrior, feathered,
# Nearest to know: wrong, you, didn, undercover, why, conviction, something, ve,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7756 0.1134 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8440 0.1117 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7902 0.1150 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9029 0.1143 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8371 0.1130 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8613 0.1130 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8572 0.0761 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8314 0.1150 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8237 0.1146 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8750 0.1128 sec/batch
# Nearest to of: the, in, and, a, by, s, one, from,
# Nearest to one: two, five, three, four, nine, six, eight, zero,
# Nearest to the: in, of, a, this, and, on, an, to,
# Nearest to to: the, a, in, they, and, for, with, by,
# Nearest to a: the, in, of, from, which, to, and, s,
# Nearest to and: in, the, of, with, as, a, to, by,
# Nearest to in: the, of, and, a, after, by, to, which,
# Nearest to two: zero, three, one, five, four, six, seven, nine,
# Nearest to file: files, draw, realtime, suki, filename, subroutines, rev, metering,
# Nearest to bbc: december, news, day, days, remaining, ibu, uktv, fine,
# Nearest to existence: universe, principle, ary, cosmological, exists, baur, phraseology, universals,
# Nearest to heavy: treacherous, telemark, thracian, cmf, significant, cause, infarction, hammering,
# Nearest to animals: axiomatization, rspca, pigs, herm, peano, primates, crayfish, cryptology,
# Nearest to units: unit, counties, regiment, si, forces, disambiguation, wintered, neutralization,
# Nearest to universe: cosmological, existence, intelligent, proposed, efe, cosmology, proton, warrior,
# Nearest to know: wrong, why, didn, undercover, you, conviction, ve, seem,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8261 0.1136 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8126 0.1128 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8117 0.1135 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8113 0.1121 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8391 0.1127 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8232 0.1141 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8789 0.1151 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7104 0.1137 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8124 0.1155 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7908 0.1161 sec/batch
# Nearest to of: the, in, and, a, see, as, by, also,
# Nearest to one: five, two, four, three, six, zero, nine, eight,
# Nearest to the: in, of, a, this, and, which, by, an,
# Nearest to to: the, a, and, they, in, with, for, from,
# Nearest to a: in, the, which, of, from, and, to, as,
# Nearest to and: in, of, the, as, with, a, to, also,
# Nearest to in: the, of, and, a, which, by, as, after,
# Nearest to two: zero, three, four, one, five, six, seven, nine,
# Nearest to file: files, draw, suki, realtime, filename, username, rev, metering,
# Nearest to bbc: december, news, uktv, ibu, days, fine, day, remaining,
# Nearest to existence: universe, principle, ary, exists, cosmological, ufo, universals, concept,
# Nearest to heavy: telemark, thracian, cmf, cause, treacherous, significant, hammering, axopods,
# Nearest to animals: rspca, axiomatization, pigs, peano, herm, cryptology, primates, steward,
# Nearest to units: unit, counties, si, regiment, forces, lysosomes, wintered, disarray,
# Nearest to universe: cosmological, existence, proposed, intelligent, cosmology, efe, proton, abundances,
# Nearest to know: wrong, you, conviction, why, didn, undercover, ve, something,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7498 0.1154 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7958 0.1154 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8670 0.1136 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8294 0.1134 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8097 0.1148 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9137 0.1131 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8292 0.1137 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8288 0.1142 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8293 0.1145 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8405 0.1147 sec/batch
# Nearest to of: the, in, and, a, as, by, s, see,
# Nearest to one: five, two, four, three, six, zero, nine, eight,
# Nearest to the: in, of, a, this, and, which, an, first,
# Nearest to to: in, the, and, a, they, for, by, with,
# Nearest to a: the, in, of, which, and, from, s, an,
# Nearest to and: in, the, of, as, with, a, to, by,
# Nearest to in: the, of, and, a, which, to, as, with,
# Nearest to two: three, zero, four, one, five, six, seven, nine,
# Nearest to file: files, draw, filename, suki, realtime, username, rev, metering,
# Nearest to bbc: december, news, uktv, ibu, days, doctor, fine, remaining,
# Nearest to existence: universe, principle, cosmological, baur, universals, concept, ary, ufo,
# Nearest to heavy: telemark, cause, thracian, cmf, significant, infarction, axopods, heaviest,
# Nearest to animals: rspca, pigs, axiomatization, peano, primates, herm, crayfish, calves,
# Nearest to units: unit, si, regiment, counties, forces, lysosomes, neutralization, metrology,
# Nearest to universe: cosmological, existence, intelligent, cosmology, proposed, efe, fictional, proton,
# Nearest to know: wrong, you, didn, why, conviction, undercover, something, ve,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8628 0.1143 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8472 0.1130 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8384 0.1124 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8159 0.1117 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8639 0.1131 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8416 0.1136 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8688 0.1130 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8296 0.1150 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8291 0.1144 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7959 0.1145 sec/batch
# Nearest to of: the, in, and, a, by, one, s, for,
# Nearest to one: five, four, three, two, zero, six, nine, eight,
# Nearest to the: in, of, this, a, and, by, to, which,
# Nearest to to: the, in, and, a, for, from, by, they,
# Nearest to a: the, in, which, of, from, to, s, and,
# Nearest to and: in, of, the, with, to, one, six, as,
# Nearest to in: the, of, and, a, to, which, by, after,
# Nearest to two: zero, three, four, one, five, six, seven, nine,
# Nearest to file: files, filename, draw, realtime, username, suki, requests, document,
# Nearest to bbc: december, news, uktv, ibu, fine, days, doctor, sitcoms,
# Nearest to existence: universe, principle, cosmological, ary, baur, universals, exists, phraseology,
# Nearest to heavy: thracian, telemark, influenced, decaying, cause, significant, assimilation, cmf,
# Nearest to animals: rspca, pigs, axiomatization, herm, peano, primates, calves, locomotion,
# Nearest to units: unit, si, regiment, counties, forces, wintered, lysosomes, stanislaus,
# Nearest to universe: cosmological, existence, intelligent, cosmology, efe, proposed, fictional, warrior,
# Nearest to know: wrong, why, you, didn, undercover, something, ve, conviction,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8529 0.1158 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8430 0.1143 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9215 0.1131 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8965 0.1129 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8905 0.1135 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8345 0.1133 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7778 0.1146 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8237 0.1134 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7603 0.1145 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8455 0.1144 sec/batch
# Nearest to of: the, in, and, a, by, s, also, from,
# Nearest to one: five, two, four, nine, six, three, eight, zero,
# Nearest to the: in, of, this, a, and, by, an, on,
# Nearest to to: a, the, in, and, they, from, with, but,
# Nearest to a: the, in, of, which, from, and, to, s,
# Nearest to and: in, of, the, with, a, one, as, other,
# Nearest to in: the, of, a, and, after, which, with, as,
# Nearest to two: zero, three, five, one, four, six, seven, nine,
# Nearest to file: files, filename, draw, suki, realtime, username, subroutines, requests,
# Nearest to bbc: december, news, days, ibu, uktv, day, remaining, fine,
# Nearest to existence: universe, principle, cosmological, universals, ufo, baur, ary, that,
# Nearest to heavy: telemark, thracian, significant, influenced, treacherous, decaying, stylings, cmf,
# Nearest to animals: pigs, axiomatization, rspca, herm, peano, primates, locomotion, steward,
# Nearest to units: unit, si, regiment, forces, counties, lysosomes, wintered, per,
# Nearest to universe: cosmological, existence, intelligent, cosmology, efe, proposed, warrior, fictional,
# Nearest to know: wrong, didn, why, undercover, you, ve, something, sarcastic,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8313 0.1141 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8331 0.1123 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
